# %% [markdown]
# <h3>Генератор равномерного распределения</h3>

# %%
import matplotlib.pyplot as plt
from MersenneTwister import MersenneTwister

mt = MersenneTwister()
n = 10000

random_floats = [mt.genrand_float() for _ in range(n)]

plt.hist(random_floats, bins=50, density=True, alpha=0.6, color='b')
plt.title('Равномерное распределение сгенерированных чисел')
plt.xlabel('Значение')
plt.ylabel('Плотность')
plt.grid(True)
plt.show()

# %% [markdown]
# <h3>Генератор других распределений</h3>

# %%
from DistributionSampler import DistributionSampler
import numpy as np

mt = MersenneTwister()
sampler = DistributionSampler(mt)

# %%
lambd = 2
exp_samples = [sampler.exponential(lambd) for _ in range(10000)]

plt.hist(exp_samples, bins=50, density=True, alpha=0.6, color='g')
x = np.linspace(0, max(exp_samples), 100)
plt.plot(x, lambd * np.exp(-lambd * x), 'r', label="Теоретическая плотность")
plt.legend()
plt.title("Экспоненциальное распределение")
plt.xlabel("Значение")
plt.ylabel("Плотность")
plt.grid(True)
plt.show()

# %%
normal_samples = [sampler.normal() for _ in range(10000)]

plt.hist(normal_samples, bins=50, density=True, alpha=0.6, color='b')
x = np.linspace(-4, 4, 100)
plt.title("Нормальное распределение")
plt.xlabel("Значение")
plt.ylabel("Плотность")
plt.grid(True)
plt.show()

# %% [markdown]
# <h2>Симуляция</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erfinv
from collections import deque
import heapq
import random
from DistributionSampler import DistributionSampler
from MersenneTwister import MersenneTwister
from models.Library import Library
from models.Librarian import Librarian
from models.User import User

def simulate_library(num_books=3, copies_per_book=2, num_librarians=2, num_users=12, arrival_rate=1/5, librarian_mean=2, librarian_std=0.5, user_mean=30, user_std=5):
    generator = MersenneTwister()
    sampler = DistributionSampler(generator)
    library = Library(num_books=num_books, copies_per_book=copies_per_book, num_librarians=num_librarians, generator=generator, normal_mean_librarian=librarian_mean, normal_std_librarian=librarian_std)
    users = [User(i, generator, normal_mean=user_mean, normal_std=user_std) for i in range(num_users)]
    events = []
    current_time = 0

    for user in users:
        book_name = f"Book_{random.randint(0, num_books - 1)}"
        current_time += sampler.exponential(arrival_rate)
        event_time, success = library.request_book(user, book_name, current_time)
        if success:
            reading_time = user.decide_reading_time()
            heapq.heappush(events, (event_time + reading_time, user, book_name))
    
    while events:
        event_time, user, book_name = heapq.heappop(events)
        new_time, next_user = library.return_book(user, book_name, event_time)
        if next_user:
            reading_time = next_user.decide_reading_time()
            heapq.heappush(events, (new_time + reading_time, next_user, book_name))
    
    avg_wait_time = sum(library.wait_times) / len(library.wait_times)
    avg_librarian_workload = sum(l.total_service_time for l in library.librarians) / len(library.librarians)

    return avg_wait_time, library.served_users, avg_librarian_workload, current_time

avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time = simulate_library(1, 1, 1, 10, 1/2, 2, 0.5, 30, 5)

print(f"Среднее время ожидания: {avg_wait_time:.2f} минут")
print(f"Количество обслуженных клиентов за минуту: {overall_simulation_time / served_users}")
print(f"Среднее время работы библиотекарей: {avg_librarian_workload:.2f} минут")
# Out:
# Среднее время ожидания: 139.02 минут
# Количество обслуженных клиентов за минуту: 2.7614895783242437
# Среднее время работы библиотекарей: 42.28 минут

# %%
import time

start_time = time.time()
N = 1_000_000
results = []

params = {
    'num_books': 5,
    'copies_per_book': 3,
    'num_librarians': 3,
    'num_users': 20,
    'arrival_rate': 1/4,  # Среднее время прибытия пользователей
    'librarian_mean': 2,  # Среднее время обслуживания пользователем
    'librarian_std': 0.5,  # Стандартное отклонение для времени обслуживания библиотекарем
    'user_mean': 30,  # Среднее время чтения пользователем
    'user_std': 5  # Стандартное отклонение для времени чтения
}

for i in range(N):
    avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time = simulate_library(**params)
    results.append((avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time))
    if (i % 10000 == 0):
        print(i)

end_time = time.time()
print(f"Total runtime: {end_time - start_time:.2f} seconds")
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# Total runtime: 2.08 seconds

# %% [markdown]
# <h2>Графики</h2>

# %%
avg_wait_times = [result[0] for result in results]
served_users = [result[1] for result in results]
avg_librarian_workloads = [result[2] for result in results]
overall_sim_times = [result[3] for result in results]

served_users_per_minute = [users / (sim_time / 60) for users, sim_time in zip(served_users, overall_sim_times)]

mean_wait_time = np.mean(avg_wait_times)
mean_served_per_minute = np.mean(served_users_per_minute)
mean_librarian_workload = np.mean(avg_librarian_workloads)

fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))


axes[0].plot(avg_wait_times, color='blue', label="Время ожидания")
axes[0].axhline(mean_wait_time, color='red', linestyle="--", label=f"Среднее: {mean_wait_time:.2f}")
axes[0].set_title('Среднее время ожидания пользователей')
axes[0].set_xlabel('Итерации')
axes[0].set_ylabel('Время ожидания (сек.)')
axes[0].grid(True)
axes[0].legend()

axes[1].plot(served_users_per_minute, color='green', label="Обслужено в минуту")
axes[1].axhline(mean_served_per_minute, color='red', linestyle="--", label=f"Среднее: {mean_served_per_minute:.2f}")
axes[1].set_title('Количество обслуженных пользователей в минуту')
axes[1].set_xlabel('Итерации')
axes[1].set_ylabel('Пользователей/мин')
axes[1].grid(True)
axes[1].legend()

axes[2].plot(avg_librarian_workloads, color='orange', label="Загрузка библиотекарей")
axes[2].axhline(mean_librarian_workload, color='red', linestyle="--", label=f"Среднее: {mean_librarian_workload:.2f}")
axes[2].set_title('Средняя загрузка библиотекарей')
axes[2].set_xlabel('Итерации')
axes[2].set_ylabel('Средняя загрузка')
axes[2].grid(True)
axes[2].legend()

plt.tight_layout()
plt.show()

# %%
import itertools
import pandas as pd
import matplotlib.pyplot as plt

# Define parameter ranges
num_books_range = range(1, 31)  # 1 to 30
copies_per_book_range = range(1, 6)  # 1 to 5
num_librarians_range = range(1, 11)  # 1 to 10
num_users_range = range(10, 51, 10)  # 10, 20, 30, 40, 50
arrival_rate_range = [1/2, 1/5, 1/10]  # Different arrival rates
librarian_mean_range = range(2, 6)  # 2 to 5
user_mean_range = range(20, 61, 10)  # 20, 30, 40, 50, 60

# Fixed parameters
librarian_std = 0.5
user_std = 5

# Generate all parameter combinations
combinations = itertools.product(
    num_books_range, copies_per_book_range, num_librarians_range, num_users_range,
    arrival_rate_range, librarian_mean_range, user_mean_range
)

results = []

for combo in combinations:
    params = {
        'num_books': combo[0],
        'copies_per_book': combo[1],
        'num_librarians': combo[2],
        'num_users': combo[3],
        'arrival_rate': combo[4],
        'librarian_mean': combo[5],
        'librarian_std': librarian_std,
        'user_mean': combo[6],
        'user_std': user_std
    }
    
    #avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time = simulate_library(**params)
    print(f"{params}")
    #avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time = simulate_library(1, 1, 1, 10, 1/2, 2, 0.5, 30, 5)

    results.append({
        **params,
        'average wait time': avg_wait_time,
        'served users per minute': overall_simulation_time / served_users,
        'average librarian workload': avg_librarian_workload,
        'overall simulation time': overall_simulation_time
    })

# Convert results to DataFrame
df = pd.DataFrame(results)

df.to_csv("simulation_results.csv", index=False)

# Visualization
plt.figure(figsize=(10, 5))
plt.hist(df['avg_wait_time'], bins=20, alpha=0.7, label='Avg Wait Time')
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.legend()
plt.title("Histogram of Average Wait Time")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(df['num_books'], df['avg_wait_time'], 'bo', alpha=0.5)
plt.xlabel("Number of Books")
plt.ylabel("Average Wait Time")
plt.title("Impact of Number of Books on Wait Time")
plt.show()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 10, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 20, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 30, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 2, 'num_librarians': 2, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# ...
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 40, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.5, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.2, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 2, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 3, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 4, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 20, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 30, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 40, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 50, 'user_std': 5}
# {'num_books': 30, 'copies_per_book': 5, 'num_librarians': 10, 'num_users': 50, 'arrival_rate': 0.1, 'librarian_mean': 5, 'librarian_std': 0.5, 'user_mean': 60, 'user_std': 5}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avg_wait_time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 58
#      56 # Visualization
#      57 plt.figure(figsize=(10, 5))
# ---> 58 plt.hist(df['avg_wait_time'], bins=20, alpha=0.7, label='Avg Wait Time')
#      59 plt.xlabel("Time")
#      60 plt.ylabel("Frequency")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'avg_wait_time'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Define parameter ranges
num_books_range = range(1, 31)  # 1 to 30
copies_per_book_range = range(1, 6)  # 1 to 5
num_librarians_range = range(1, 11)  # 1 to 10
num_users_range = range(10, 51, 10)  # 10, 20, 30, 40, 50
arrival_rate_range = [1/10, 1/5, 1/2]  # Different arrival rates
librarian_mean_range = range(2, 6)  # 2 to 5
user_mean_range = range(20, 61, 10)  # 20, 30, 40, 50, 60

# Fixed parameters
librarian_std = 0.5
user_std = 5

results = []

for num_books in num_books_range:
    print(f"{num_books} from 30")
    for copies_per_book in copies_per_book_range:
        for num_librarians in num_librarians_range:
            for num_users in num_users_range:
                for arrival_rate in arrival_rate_range:
                    for librarian_mean in librarian_mean_range:   
                        for user_mean in user_mean_range:
                            params = {
                                'num_books': num_books,
                                'copies_per_book': copies_per_book,
                                'num_librarians': num_librarians,
                                'num_users': num_users,
                                'arrival_rate': arrival_rate,
                                'librarian_mean': librarian_mean,
                                'librarian_std': librarian_std,
                                'user_mean': user_mean,
                                'user_std': user_std
                            }
                            avg_wait_time, served_users, avg_librarian_workload, overall_simulation_time = simulate_library(**params)
                            
                            results.append({
                                **params,
                                'avg_wait_time': avg_wait_time,
                                'served_users': served_users,
                                'avg_librarian_workload': avg_librarian_workload,
                                'overall_simulation_time': overall_simulation_time,
                                'clients_per_minute': overall_simulation_time / served_users if served_users > 0 else 0
                            })

# Convert results to DataFrame
df = pd.DataFrame(results)
df.to_csv("simulation_results.csv", index=False)
# Out:
# 1 from 30
# 2 from 30
# 3 from 30
# 4 from 30
# 5 from 30
# 6 from 30
# 7 from 30
# 8 from 30
# 9 from 30
# 10 from 30
# 11 from 30
# 12 from 30
# 13 from 30
# 14 from 30
# 15 from 30
# 16 from 30
# 17 from 30
# 18 from 30
# 19 from 30
# 20 from 30
# 21 from 30
# 22 from 30
# 23 from 30
# 24 from 30
# 25 from 30
# 26 from 30
# 27 from 30
# 28 from 30
# 29 from 30
# 30 from 30

# %%
# Visualization
plt.figure(figsize=(10, 5))
plt.hist(df['avg_wait_time'], bins=20, alpha=0.7, label='Avg Wait Time')
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.legend()
plt.title("Histogram of Average Wait Time")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(df['num_books'], df['avg_wait_time'], 'bo', alpha=0.5)
plt.xlabel("Number of Books")
plt.ylabel("Average Wait Time")
plt.title("Impact of Number of Books on Wait Time")
plt.show()
